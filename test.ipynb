# %%
import os
from google import genai
import asyncio
import nest_asyncio
nest_asyncio.apply()
#from mcp import ClientSession, StdioServerParameters
#from mcp.client.stdio import stdio_client
from fastmcp import Client
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       5 nest_asyncio.apply()
#       6 #from mcp import ClientSession, StdioServerParameters
#       7 #from mcp.client.stdio import stdio_client
# ----> 8 from fastmcp import Client
#
# File ~/miniforge3/envs/pyg/lib/python3.10/site-packages/fastmcp/__init__.py:5
#       3 import warnings
#       4 from importlib.metadata import version as _version
# ----> 5 from fastmcp.settings import Settings
#       6 from fastmcp.utilities.logging import configure_logging as _configure_logging
#       8 settings = Settings()
#
# File ~/miniforge3/envs/pyg/lib/python3.10/site-packages/fastmcp/settings.py:58
#      54 class ExtendedSettingsConfigDict(SettingsConfigDict, total=False):
#      55     env_prefixes: list[str] | None
# ---> 58 class Settings(BaseSettings):
#      59     """FastMCP settings."""
#      61     model_config = ExtendedSettingsConfigDict(
#      62         env_prefixes=["FASTMCP_", "FASTMCP_SERVER_"],
#      63         env_file=".env",
#    (...)
#      66         nested_model_default_partial_update=True,
#      67     )
#
# File ~/miniforge3/envs/pyg/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py:242, in ModelMetaclass.__new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#     238     parent_namespace = unpack_lenient_weakvaluedict(parent_namespace)
#     240 ns_resolver = NsResolver(parent_namespace=parent_namespace)
# --> 242 set_model_fields(cls, config_wrapper=config_wrapper, ns_resolver=ns_resolver)
#     244 # This is also set in `complete_model_class()`, after schema gen because they are recreated.
#     245 # We set them here as well for backwards compatibility:
#     246 cls.__pydantic_computed_fields__ = {
#     247     k: v.info for k, v in cls.__pydantic_decorators__.computed_fields.items()
#     248 }
#
# File ~/miniforge3/envs/pyg/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py:566, in set_model_fields(cls, config_wrapper, ns_resolver)
#     558 """Collect and set `cls.__pydantic_fields__` and `cls.__class_vars__`.
#     559
#     560 Args:
#    (...)
#     563     ns_resolver: Namespace resolver to use when getting model annotations.
#     564 """
#     565 typevars_map = get_model_typevars_map(cls)
# --> 566 fields, class_vars = collect_model_fields(cls, config_wrapper, ns_resolver, typevars_map=typevars_map)
#     568 cls.__pydantic_fields__ = fields
#     569 cls.__class_vars__.update(class_vars)
#
# File ~/miniforge3/envs/pyg/lib/python3.10/site-packages/pydantic/_internal/_fields.py:363, in collect_model_fields(cls, config_wrapper, ns_resolver, typevars_map)
#     360     assigned_value.default = default
#     361     assigned_value._attributes_set['default'] = default
# --> 363 field_info = FieldInfo_.from_annotated_attribute(ann_type, assigned_value, _source=AnnotationSource.CLASS)
#     364 # Store the original annotation and assignment value that should be used to rebuild the field info later.
#     365 # Note that the assignment is always stored as the annotation might contain a type var that is later
#     366 #  parameterized with an unknown forward reference (and we'll need it to rebuild the field info):
#     367 field_info._original_assignment = assigned_value
#
# File ~/miniforge3/envs/pyg/lib/python3.10/site-packages/pydantic/fields.py:468, in FieldInfo.from_annotated_attribute(annotation, default, _source)
#     464 else:
#     465     # `default` is the actual default value
#     466     attr_overrides['default'] = default
# --> 468 field_info = FieldInfo._construct(
#     469     prepend_metadata + metadata if prepend_metadata is not None else metadata, **attr_overrides
#     470 )
#     471 field_info._qualifiers = inspected_ann.qualifiers
#     472 field_info._final = True
#
# File ~/miniforge3/envs/pyg/lib/python3.10/site-packages/pydantic/fields.py:563, in FieldInfo._construct(cls, metadata, **attr_overrides)
#     560         merged_metadata.append(meta)
#     562 merged_kwargs.update(attr_overrides)
# --> 563 merged_field_info = cls(**merged_kwargs)
#     564 merged_field_info.metadata = merged_metadata
#     565 return merged_field_info
#
# File ~/miniforge3/envs/pyg/lib/python3.10/site-packages/pydantic/fields.py:252, in FieldInfo.__init__(self, **kwargs)
#     249 self.default_factory = kwargs.pop('default_factory', None)
#     251 if self.default is not PydanticUndefined and self.default_factory is not None:
# --> 252     raise TypeError('cannot specify both default and default_factory')
#     254 self.alias = kwargs.pop('alias', None)
#     255 self.validation_alias = kwargs.pop('validation_alias', None)
#
# TypeError: cannot specify both default and default_factory

# %%
import networkx

# %%
server_code = r'''
from __future__ import annotations

from datetime import datetime, timezone
from fastmcp import FastMCP

mcp = FastMCP("Demo MCP Server")

@mcp.tool
def add(a: float, b: float) -> float:
    """Add two numbers and return the sum."""
    return a + b

@mcp.tool
def now_utc_iso() -> str:
    """Return the current UTC time as an ISO-8601 string."""
    return datetime.now(timezone.utc).isoformat()

if __name__ == "__main__":
    mcp.run()
'''
open("mcp_server.py", "w", encoding="utf-8").write(server_code)
print("Wrote mcp_server.py")
# Out:
# Wrote mcp_server.py

# %%
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="What was thw battle of Hastings?"
)
print(response.text)
# Out:
# The **Battle of Hastings** was a pivotal military engagement fought on **October 14, 1066**, at Senlac Hill (modern-day Battle, East Sussex), near Hastings, England.
#
# Here's a breakdown of its key aspects:
#
# 1.  **Who Fought:**
#     *   The **Norman-French army** led by **William, Duke of Normandy** (who would become William the Conqueror).
#     *   The **English army** led by **King Harold Godwinson**.
#
# 2.  **Why it Happened (Causes):**
#     *   **Succession Crisis:** England's King Edward the Confessor died childless in January 1066.
#     *   **Conflicting Claims:** Harold Godwinson, the most powerful English earl, was crowned king shortly after Edward's death. However, William of Normandy claimed that Edward had promised him the throne and that Harold had previously sworn an oath to support his claim.
#     *   **Invasion:** William, with the Pope's blessing, gathered a large invasion fleet and army, landing in Pevensey Bay (Sussex) on September 28, 1066.
#     *   **Harold's Challenge:** Harold had just fought and defeated a Norwegian invasion led by Harald Hardrada and his own rebellious brother Tostig at the Battle of Stamford Bridge in northern England on September 25. Upon hearing of William's landing, he was forced to march his exhausted army rapidly south to confront the Normans.
#
# 3.  **Key Events of the Battle:**
#     *   **English Defensive Position:** Harold's army took up a strong defensive position on Senlac Hill, forming a formidable "shield wall" that was difficult for the Norman cavalry and archers to break.
#     *   **Norman Tactics:** William's forces repeatedly attacked the English shield wall. They employed a combination of archers, infantry, and heavy cavalry. Crucially, the Normans used "feigned retreats" – pretending to flee, drawing segments of the English line to break formation and pursue, only to turn and be cut down by the returning Norman cavalry.
#     *   **Harold's Death:** Towards the end of the day, after hours of fierce fighting, King Harold was killed (traditionally by an arrow to the eye, though some accounts suggest he was cut down by Norman knights).
#     *   **English Collapse:** With their king dead and their formations broken, the remaining English forces routed and fled.
#
# 4.  **Outcome and Significance:**
#     *   **Decisive Norman Victory:** The Battle of Hastings was a decisive victory for William.
#     *   **Norman Conquest of England:** This battle effectively marked the beginning of the Norman Conquest. William marched on London and was crowned King of England on Christmas Day, 1066.
#     *   **Profound Changes:** The Norman Conquest had a massive and lasting impact on England, fundamentally transforming its:
#         *   **Language:** Old English was heavily influenced by Norman French, leading to Middle English and eventually modern English.
#         *   **Government & Law:** A more centralized monarchy and the introduction of a feudal system.
#         *   **Culture:** Norman architecture (castles), customs, and aristocracy replaced much of the Anglo-Saxon elite.
#         *   **International Relations:** Tied England more closely to continental Europe, especially France.
#
# The Battle of Hastings is one of the most significant events in English history, marking the end of Anglo-Saxon rule and ushering in a new Norman era that shaped the nation for centuries to come.
